# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.xkcd()
plt.title('My  name  is',color='darkblue',fontsize=22)
plt.axis([0,38,0,25])
xx1 = np.linspace(5,10,200)
xy1 = np.linspace(5,20,200)
xy2 = np.linspace(20,5,200)
plt.plot(xx1,xy1,linewidth = '4')
plt.plot(xx1,xy2,linewidth = '4')

ex1 = np.linspace(11,15,200)
ey1 = np.linspace(5,5,200)
ey2 = np.linspace(12.5,12.5,200)
ey3 = np.linspace(20,20,200)
plt.plot(ex1,ey1,linewidth = '4')
plt.plot(ex1,ey2,linewidth = '4')
plt.plot(ex1,ey3,linewidth = '4')
ex2 = np.linspace(11,11,200)
ey4 = np.linspace(5,20,200)
plt.plot(ex2,ey4,linewidth = '4')

nx1 = np.linspace(16,16,200)
nx2 = np.linspace(21,21,200)
ny1 = np.linspace(5,20,200)
plt.plot(nx1,ny1,linewidth = '4')
plt.plot(nx2,ny1,linewidth = '4')
nx3 = np.linspace(16,21,200)
ny2 = np.linspace(20,5,200)
plt.plot(nx3,ny2,linewidth = '4')

ix = np.linspace(24,24,200)
iy = np.linspace(5,20,200)
plt.plot(ix,iy,linewidth = '4')
ix1 = np.linspace(22,26,200)
plt.plot(ix1,ey1,linewidth = '4')
plt.plot(ix1,ey3,linewidth = '4')

nx1 = np.linspace(27,30,200)
nx2 = np.linspace(30,33,200)
plt.plot(nx1,xy1,linewidth = '4')
plt.plot(nx2,xy2,linewidth = '4')
nx3 = np.linspace(28.5,31.5,200)
plt.plot(nx3,ey2,linewidth = '4')
